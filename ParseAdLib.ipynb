# %%
from html.parser import HTMLParser

class MyAdlibHTMLParser(HTMLParser):
    def update(self):
        self.foundContent = False
        self.getLabel = False
        self.getValue = False
        self.getListFirst  = False
        self.getList = False
        self.currentLabel = ''
        self.currentValue = ''
        self.d = {}

    def handle_starttag(self, tag, attrs):
        dir(self)
        if tag == 'ul': 
            self.foundContent = True
        if self.foundContent: 
            if tag == 'div':
                #print("Encountered a start tag:", tag, attrs)
                if attrs[-1][-1] == 'label': 
                    self.getLabel = True
                    self.getValue = False
                    self.getListFirst  = False
                    self.getList  = False
                if attrs[-1][-1] == 'value': 
                    self.getLabel = False
                    self.getValue = True
                    self.getListFirst  = False
                    self.getList  = False
                if attrs[-1][-1] == 'separateline-first':                     
                    self.getLabel = False
                    self.getValue = False
                    self.getListFirst = True
                    self.getList  = False
                if attrs[-1][-1] == 'separateline':                     
                    self.getLabel = False
                    self.getValue = False
                    self.getListFirst = False
                    self.getList  = True
            if tag == 'a':  
                if attrs[0][1] == 'ais-pdf': 
                    self.d['hyperref'] = attrs[1][1]
    def handle_endtag(self, tag):
        if self.foundContent: 
            #print("Encountered an end tag :", tag)
            if tag == 'ul': 
                self.foundContent = False

    def handle_data(self, data):
        if self.foundContent: 
            #print("Encountered some data  :", data)
            if self.getLabel: 
                self.currentLabel = data
                self.getLabel = False
            if self.getValue: 
                self.currentValue = data
                self.getValue = False
                self.d[self.currentLabel] = self.currentValue
            if self.getListFirst: 
                self.currentValue = data
                self.getListFirst = False
                self.d[self.currentLabel] = [self.currentValue]
            if self.getList: 
                self.currentValue = data
                self.getValue = False
                self.d[self.currentLabel].append(self.currentValue)

def parse_adlib_catalog_entry(html_file):
    parser = MyAdlibHTMLParser()
    parser.update()
    
    with open(html_file,'r', encoding="utf8") as f: 
        text = f.read()
        parser.feed(text)
    entry = parser.d
    authors = [author[::-1].strip()[::-1].split(' ') for author in entry['Author']]
    authorslistbib = []

    for author in authors: 
        if len(author) > 2: 
            inbetween = ' '.join(author[1:-1])
            authorbib = f"{'{'}\\van{'{'+author[-1]+'}{'+inbetween.capitalize()+'}{'+inbetween+'}'}{'}'} {author[-1]}, {author[0]}"
        else:
            authorbib = f"{author[1]}, {author[0]}"
        authorslistbib.append(authorbib)

    entry['Author'] = '{' + ' and '.join(authorslistbib) + '}'

    entry['Citekey'] = ''.join(authors[0][1:]) +entry['Year of publication'][2:4]        
    return entry

def save_file(entry):
    import shutil, os, subprocess
    os.getcwd()
    if not os.path.exists('adlib'):
        os.mkdir('adlib')
    path, filename = os.path.split(entry['hyperref'])
    _, ext = os.path.splitext(filename)
    dfilename = os.path.split(entry['hyperref'])[-1]
    if not os.path.exists(dfilename):
        subprocess.run(r"curl -O " + entry['hyperref'])
    fullfilename = os.path.join('adlib',entry['Citekey']+ext)
    if not os.path.exists(fullfilename):
        shutil.copyfile(dfilename, fullfilename)
        print(f"Digital document saved to: {fullfilename}")
    else:
        if os.path.getsize(dfilename) == os.path.getsize(fullfilename): 
            print(f"Digital document {fullfilename} already exists")
            return 1
        return 0
    return 1
        
def bibtex(entry):
    bibtex_entry = ( 
    f"@techreport{'{'+entry['Citekey']}, \n"
    f"  author      = {entry['Author']},\n"
    f"  title       = {'{{'+entry['Title']+'}}'},\n"
    f"  institution = {'{'+entry['Publisher']}, {entry['Place of publication']+'}'},\n"
    f"  year        = {'{'+entry['Year of publication'][0:4]+'}'},\n"
    f"  type        = {'{'+entry['Material']+'}'},\n"
    )
    if 'Pagination' in entry.keys(): 
        bibtex_entry += f"  pages      = {'{'+entry['Pagination']+'}'},\n" 
    bibtex_entry += (
    f"  address     = {'{'+'}'},\n"
    f"  month       = {'{'+entry['Year of publication'][4:]+'}'},\n"
    f"  note        = {'{'+'}'},\n"
    f"  annote      = {'{'+'}'},\n"
      )

    for key in list(set(entry.keys()) - set(['Citekey','Title','Author','Publisher','Place of publication','Year of publication','Material','Pagination'])):
        print(key)
        bibtex_entry += f"  {key.replace(' ','').lower():<10} = {'{'+str(entry[key])+'}'},\n"


    bibtex_entry += "}\n"
    
    return bibtex_entry

def generate_bib(filename): 
    import os
    entry = parse_adlib_catalog_entry(filename)
    print(entry)
    base, ext = os.path.splitext(filename)
    save_file(entry)
    bibentry = bibtex(entry)
    print(bibentry)
    bibfile = os.path.join('adlib',entry['Citekey']+'.bib')
    if not os.path.exists(bibfile): 
        with open(bibfile, 'w') as f:
            f.writelines(bibentry)
            print(f"Bibliography document saved to: {bibfile}")
    else: 
        print(f"Bibliography document {bibfile} already exists")

# %%
import glob
for file in glob.glob('fullCatalogue*.html'):
    generate_bib(file)
# Out:
# {'Title': 'Advies uitvoering en monitoring 2e suppletie Bovenrijn', 'Author': '{Becker, A.}', 'Project number': '11200877', 'Place of publication': 'Delft', 'Publisher': 'Deltares', 'Year of publication': '2017 (okt.)', 'Pagination': '37, [50] p.', 'Illustrations': 'fig.', 'Material': 'rapport Deltares', 'hyperref': 'https://kennisbank.deltares.nl/repos/11200877_000.pdf', 'Keywords': 'rivierverbetering, rivierbodem, bodembescherming, bodemligging', 'Geographical keyword': 'Boven-Rijn', 'Citekey': 'Becker17'}
# Keywords
# Project number
# hyperref
# Geographical keyword
# Illustrations
# @techreport{Becker17,
#   author      = {Becker, A.},
#   title       = {{Advies uitvoering en monitoring 2e suppletie Bovenrijn}},
#   institution = {Deltares, Delft},
#   year        = {2017},
#   type        = {rapport Deltares},
#   pages      = {37, [50] p.},
#   address     = {},
#   month       = { (okt.)},
#   note        = {},
#   annote      = {},
#   keywords   = {rivierverbetering, rivierbodem, bodembescherming, bodemligging},
#   projectnumber = {11200877},
#   hyperref   = {https://kennisbank.deltares.nl/repos/11200877_000.pdf},
#   geographicalkeyword = {Boven-Rijn},
#   illustrations = {fig.},
# }
#
# Bibliography document adlib\Becker17.bib already exists
# {'Title': 'Inbouw duinhoogte- en ruwheidsvoorspellers in Delft3D- 3DMOR', 'Author': '{{\\van{Vuren}{Van}{van}} Vuren, S. and Ottevanger, W.}', 'Place of publication': 'Delft', 'Publisher': 'WL Delft Hydraulics', 'Year of publication': '2006 (nov.)', 'Material': 'rapport Deltares', 'hyperref': 'https://kennisbank.deltares.nl/repos/Q4190.pdf', 'Keywords': 'rivierduinen, river dunes, bodemruwheid, bed roughness, riviermorfologie, river morphology, morfologische modellen, morphological models, driedimensionale modellen, three-dimensional models', 'Citekey': 'vanVuren06'}
# Digital document saved to: adlib\vanVuren06.pdf
# hyperref
# Keywords
# @techreport{vanVuren06,
#   author      = {{\van{Vuren}{Van}{van}} Vuren, S. and Ottevanger, W.},
#   title       = {{Inbouw duinhoogte- en ruwheidsvoorspellers in Delft3D- 3DMOR}},
#   institution = {WL Delft Hydraulics, Delft},
#   year        = {2006},
#   type        = {rapport Deltares},
#   address     = {},
#   month       = { (nov.)},
#   note        = {},
#   annote      = {},
#   hyperref   = {https://kennisbank.deltares.nl/repos/Q4190.pdf},
#   keywords   = {rivierduinen, river dunes, bodemruwheid, bed roughness, riviermorfologie, river morphology, morfologische modellen, morphological models, driedimensionale modellen, three-dimensional models},
# }
#
# Bibliography document saved to: adlib\vanVuren06.bib
# {'Title': 'Beheer van dynamische oevers', 'Author': '{Mosselman, E. and Duro, G. and {\\van{Deijl}{Van der}{van der}} Deijl, E. and Eijsberg-Bak, C.I. and Buijse, T.}', 'Project number': '11205234', 'Place of publication': 'Delft', 'Publisher': 'Deltares', 'Year of publication': '2021 (mar.)', 'Pagination': '62 p.', 'Illustrations': 'fig., ref.', 'Material': 'rapport Deltares', 'hyperref': 'https://kennisbank.deltares.nl/repos/11205234_012_0001.pdf', 'Keywords': 'oevererosie, rivierdynamiek', 'Geographical keyword': 'Maas', 'Citekey': 'Mosselman21'}
# Digital document adlib\Mosselman21.pdf already exists
# Keywords
# Project number
# hyperref
# Geographical keyword
# Illustrations
# @techreport{Mosselman21,
#   author      = {Mosselman, E. and Duro, G. and {\van{Deijl}{Van der}{van der}} Deijl, E. and Eijsberg-Bak, C.I. and Buijse, T.},
#   title       = {{Beheer van dynamische oevers}},
#   institution = {Deltares, Delft},
#   year        = {2021},
#   type        = {rapport Deltares},
#   pages      = {62 p.},
#   address     = {},
#   month       = { (mar.)},
#   note        = {},
#   annote      = {},
#   keywords   = {oevererosie, rivierdynamiek},
#   projectnumber = {11205234},
#   hyperref   = {https://kennisbank.deltares.nl/repos/11205234_012_0001.pdf},
#   geographicalkeyword = {Maas},
#   illustrations = {fig., ref.},
# }
#
# Bibliography document adlib\Mosselman21.bib already exists
